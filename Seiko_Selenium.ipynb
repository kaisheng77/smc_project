# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from time import sleep
from getpass import getpass
import pandas as pd

# %%
PATH = r"C:\Users\user\AppData\Local\Programs\Common\chromedriver.exe"

# %%
driver = webdriver.Chrome(PATH)
driver.get("https://twitter.com/login")

# %%
subject = "SEIKO"

# %%
username = driver.find_element(By.XPATH,"//input[@name='text']")
username.send_keys("YuJade1133266")

# %%
next_button = driver.find_element(By.XPATH,"//span[contains(text(), 'Next')]")
next_button.click()

# %%
my_password = getpass() #type password
# Out:
# ········

# %%
password = driver.find_element(By.XPATH,'//input[@name="password"]')
password.send_keys(my_password)

# %%
log_in = driver.find_element(By.XPATH,"//span[contains(text(), 'Log in')]")
log_in.click()

# %%
#search item and fetch it
search_box = driver.find_element(By.XPATH, "//input[@data-testid='SearchBox_Search_Input']")
search_box.send_keys(subject)
search_box.send_keys(Keys.ENTER)

# %%
people = driver.find_element(By.XPATH,"//span[contains(text(), 'People')]")
people.click()

# %%
profile = driver.find_element(By.XPATH,f"//span[contains(text(), '{subject}')]")
profile.click()

# %%
TimeStamps=[]
Tweets=[]
Replies=[]
reTweets=[]
Likes=[]

# %%
count = 0
SCROLL_PAUSE_TIME = 0.5

# %%
while count < 30:
    articles = driver.find_elements(By.XPATH,"//article[@data-testid='tweet']")
    for article in articles:
        try:
            TimeStamp = article.find_element(By.XPATH,".//time").get_attribute('datetime')
            TimeStamps.append(TimeStamp)
            print(TimeStamp)
            Tweet = article.find_element(By.XPATH,".//div[@data-testid='tweetText']").text
            Tweets.append(Tweet)

            Reply = article.find_element(By.XPATH,".//div[@data-testid='reply']").text
            Replies.append(Reply)

            Retweet = article.find_element(By.XPATH,"//div[@data-testid='retweet']").text
            reTweets.append(Retweet)

            Like = article.find_element(By.XPATH,".//div[@data-testid='like']").text
            Likes.append(Like)
        except:
            print("Error occurred.")
            
        count+=1
        print(count)
    #Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

# %%
df = pd.DataFrame(list(zip(TimeStamps,Tweets,Replies,reTweets,Likes)),
                 columns=['TimeStamps','Tweets','Replies','reTweets','Likes'])

# %%
df
# Out:
#                   TimeStamps  \
# 0   2019-03-31T15:05:12.000Z
# 1   2019-03-26T05:39:55.000Z
# 2   2019-03-24T17:13:14.000Z
# 3   2019-03-23T13:34:56.000Z
# 4   2019-03-23T09:18:39.000Z
# 5   2019-03-22T11:06:31.000Z
# 6   2015-04-23T12:15:03.000Z
# 7   2015-04-23T09:15:11.000Z
# 8   2015-04-22T08:00:03.000Z
# 9   2015-04-21T13:26:22.000Z
# 10  2015-04-17T08:32:03.000Z
# 11  2015-04-17T07:36:55.000Z
# 12  2015-04-15T13:55:12.000Z
# 13  2015-04-14T08:44:04.000Z
# 14  2015-04-13T14:58:46.000Z
# 15  2015-04-13T14:39:23.000Z
# 16  2015-04-10T11:58:37.000Z
# 17  2015-04-10T07:49:11.000Z
# 18  2015-04-07T06:00:03.000Z
# 19  2015-03-31T10:18:33.000Z
# 20  2015-03-25T09:00:02.000Z
# 21  2015-03-24T21:09:15.000Z
# 22  2015-03-24T15:30:02.000Z
# 23  2015-03-24T10:44:19.000Z
# 24  2015-03-23T21:00:04.000Z
# 25  2015-03-23T17:27:21.000Z
# 26  2015-03-23T15:41:43.000Z
# 27  2015-03-23T10:20:59.000Z
# 28  2015-03-23T09:25:00.000Z
# 29  2015-03-23T09:24:18.000Z
# 30  2015-03-23T09:21:45.000Z
# 31  2015-03-23T09:20:21.000Z
# 32  2015-03-23T09:19:35.000Z
# 33  2015-03-22T20:22:03.000Z
# 34  2015-03-22T14:59:54.000Z
# 35  2015-03-22T10:15:24.000Z
# 36  2015-03-21T21:45:03.000Z
# 37  2015-03-21T17:31:03.000Z
#
#                                                Tweets Replies reTweets Likes
# 0   Seiko Presage introduces the richest taste in ...      68       39   127
# 1   Prospex collections in BASELWORLD2019.\nSeiko ...       8       39    57
# 2   The 1969 Quartz Astron 50th Anniversary Limite...       3       39    44
# 3   Seiko Astron 5X Series Stainless steel models....       5       39    28
# 4   Presage brings to life another expression of J...       4       39    26
# 5   The 1970 Diver's Re-creation Limited Edition.\...       4       39    24
# 6   Seiko and Darya Klishina - Over the years, Dar...                3     1
# 7   Sportura - Kinetic 3 Hands Calender - The Spor...                3     2
# 8   Grand Seiko SBGM021\nThis model, which employs...                3     2
# 9   RT \n@mistyonpointe\n Thank you to my \n@seiko...                3     1
# 10  Grand Seiko Historical Collection 62GS The re-...       1        3     5
# 11  Grand Seiko - Manufacturing process: http://yo...       1        3     9
# 12  #FanShare! Timing a proposal can mean everythi...                3
# 13  The History of Seiko Diver's Watches - The Pro...       3        3     5
# 14  Congratulations to our ambassador, Jimmie John...                3
# 15  A big congrats to our ambassador Jimmie Johnso...                3     1
# 16  Seiko Velatura and the 49er Class - We can har...                3
# 17  Seiko Velatura - Built for oceans\nEvery Velat...                3     2
# 18  Congratulations once again to Novak Djokovic! ...                3     4
# 19  The History of Seiko Diver's Watches - The wor...       1        3     6
# 20  "Grand Seiko Through Three Photographers' Eyes...                      1
# 21  Explore the new models in the Grand Seiko coll...       1              1
# 22  The Seiko Premier Novak Djokovic Special Editi...                      8
# 23  A Premier collection, designed for Novak Djoko...                      5
# 24  At the Grand Seiko wing, visitors can see the ...                      1
# 25  Novak Djokovic times it perfectly!\nYesterday,...       1             15
# 26  Grand Seiko Interactive Photobook - At the Gra...       2              2
# 27  Grand Seiko. A photographic exploration. -Gran...                      1
# 28  Baselworld 2015, Astron: http://youtu.be/gAD75...                      5
# 29  Baselworld 2015, Prospex: http://youtu.be/RaMJ...                      4
# 30  Baselworld 2015, Prospex: http://youtu.be/z-eR...                      4
# 31  Baselworld 2015, Grand Seiko: http://youtu.be/...                      3
# 32  Mr. Hattori's Opening Address at Baselworld, 2...                      3
# 33  Showcasing the testing in September 2014, that...                      2
# 34  Introducing the Mainemaster Professional 1000m...                      1
# 35  Prospex Marinemaster celebrates 50 years of Se...       2              4
# 36  The new Dual-Time caliber is showcased in a di...                      1
# 37  The Seiko Astron's Dual-Time caliber is offere...       1              1

# %%
df.to_csv("Seiko_Selenium.csv", index=False) #save into csv files
