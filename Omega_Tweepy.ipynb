# %%
import tweepy
from tweepy import OAuthHandler

consumer_key = "mW3WG37s3VLj6nGgASAKRLUZA"
consumer_secret = "N7grF3kosZOAkONlMXL2R7QihaiKlBec4LZVziQAPWIpxE5r0G"
access_token = "1643191566230769664-V6zBb3uYHBS1RKC7qARlyx19j0JTQO"
access_token_secret = "m5Ayghx9kuK8qeL92gy43gOwLul7OORswDEG0MLuft6HK"

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# ADD LIBRARY IMPORTS HERE
import json
import time
import datetime
import pytz
import pandas as pd
from google.colab import files

# %%
# SIMPLE TWEET COLLECTION - NOTHING NEW TO SEE HERE BUT NOTE THE ITEMS WE ARE INTERESTED IN AND HOW TO NAVIGATE PYTHON ARRAYS
sname = 'omegawatches'
id = []
text = []
tmp = api.user_timeline(screen_name = sname, count=30)
for t in tmp:
  id.append(t.id)
  text.append(t.text)

# %%
df = pd.DataFrame(columns = ['id', 'text'])
df['id'] = id
df['text'] = text
df
# Out:
#                      id                                               text
# 0   1674451519804940288  #Seamaster\n\nPrecision at every level. \n\n30...
# 1   1674357234124374017  #Seamaster \n\nOMEGA in Mykonos.\n\nImmerse yo...
# 2   1674009764244738051  #Seamaster \n\nPrecision at every level.\n\n12...
# 3   1673681524095434752  #Seamaster\n\nPrecision at every level.\n\nDis...
# 4   1673421040381227015  #Seamaster\n\nOMEGA in Mykonos. \n\nBe ready f...
# 5   1673028342201700354  #Seamaster \n\nPrecision at every level.\n\nJu...
# 6   1672628175103221761  It’s not just the colours that are special. In...
# 7   1672258342264209410  The magic behind the colours. Take a glimpse i...
# 8   1671899272877420544  It takes many steps of craftsmanship to create...
# 9   1671537296506535936  From a raw piece of material, each OMEGA brace...
# 10  1671489596922777603  The hands of time. Each one brought to life wi...
# ...

# %%
df.to_csv("Omega_Tweepy.csv", index=False) #save into csv files
